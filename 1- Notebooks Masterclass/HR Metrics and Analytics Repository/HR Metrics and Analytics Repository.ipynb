# %%
# Importing libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# Reading the dataset
df = pd.read_csv('/kaggle/input/hr-metrics-and-analytics-repository/HR Data.xlsx - HR data.csv')

# Displaying the first few rows of the dataset
df.head()
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Attrition                   1470 non-null   object
#  1   Business Travel             1470 non-null   object
#  2   CF_age band                 1470 non-null   object
#  3   CF_attrition label          1470 non-null   object
#  4   Department                  1470 non-null   object
#  5   Education Field             1470 non-null   object
#  6   emp no                      1470 non-null   object
#  7   Employee Number             1470 non-null   int64
#  8   Gender                      1470 non-null   object
#  9   Job Role                    1470 non-null   object
#  10  Marital Status              1470 non-null   object
#  11  Over Time                   1470 non-null   object
#  12  Over18                      1470 non-null   object
# ...

# %% [markdown]
# **How many missing values are there in each column?**

# %%
# Checking for missing values in each column
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# -2                            0
# 0                             0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# ...

# %% [markdown]
# **How is the distribution of the 'Attrition' variable?**

# %%
# Plotting the distribution of 'Attrition'
plt.figure(figsize=(8, 6))
sns.countplot(x='Attrition', data=df)
plt.title('Distribution of Attrition')
plt.show()

# %% [markdown]
# **What is the distribution of 'Age' among employees?**

# %%
# Plotting the distribution of 'Age'
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **How does 'Job Satisfaction' vary with 'Job Involvement'?**

# %%
# Creating a scatter plot for 'Job Satisfaction' vs 'Job Involvement'
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Job Satisfaction', y='Job Involvement', data=df, hue='Attrition')
plt.title('Job Satisfaction vs Job Involvement')
plt.xlabel('Job Satisfaction')
plt.ylabel('Job Involvement')
plt.legend()
plt.show()

# %% [markdown]
# **What are the counts of employees based on 'Business Travel'?**

# %%
# Plotting the counts of employees based on 'Business Travel'
plt.figure(figsize=(10, 6))
sns.countplot(x='Business Travel', data=df)
plt.title('Employee Count by Business Travel')
plt.show()

# %% [markdown]
# **How does 'Monthly Income' vary with 'Education Field'?**

# %%
# Plotting the relationship between 'Monthly Income' and 'Education Field'
plt.figure(figsize=(12, 8))
sns.boxplot(x='Education Field', y='Monthly Income', data=df)
plt.title('Monthly Income by Education Field')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **How does 'Work Life Balance' impact 'Attrition'?**

# %%
# Plotting the impact of 'Work Life Balance' on 'Attrition'
plt.figure(figsize=(10, 6))
sns.countplot(x='Work Life Balance', hue='Attrition', data=df)
plt.title('Impact of Work Life Balance on Attrition')
plt.show()

# %% [markdown]
# **How is 'Years at Company' distributed among employees?**

# %%
# Plotting the distribution of 'Years at Company'
plt.figure(figsize=(10, 6))
sns.histplot(df['Years At Company'], bins=20, kde=True)
plt.title('Distribution of Years at Company')
plt.xlabel('Years at Company')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **What is the distribution of 'Distance From Home' based on 'Marital Status'?**

# %%
# Plotting the distribution of 'Distance From Home' based on 'Marital Status'
plt.figure(figsize=(12, 8))
sns.boxplot(x='Marital Status', y='Distance From Home', data=df)
plt.title('Distribution of Distance From Home by Marital Status')
plt.show()

# %% [markdown]
# **How does 'Percent Salary Hike' relate to 'Performance Rating'?**

# %%
# Creating a scatter plot for 'Percent Salary Hike' vs 'Performance Rating'
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Percent Salary Hike', y='Performance Rating', data=df, hue='Attrition')
plt.title('Percent Salary Hike vs Performance Rating')
plt.xlabel('Percent Salary Hike')
plt.ylabel('Performance Rating')
plt.legend()
plt.show()

# %% [markdown]
# **What is the distribution of 'Total Working Years' among employees?**

# %%
# Plotting the distribution of 'Total Working Years'
plt.figure(figsize=(10, 6))
sns.histplot(df['Total Working Years'], bins=20, kde=True)
plt.title('Distribution of Total Working Years')
plt.xlabel('Total Working Years')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **How does 'Environment Satisfaction' vary with 'Job Level'?**

# %%
# Creating a boxplot for 'Environment Satisfaction' vs 'Job Level'
plt.figure(figsize=(12, 8))
sns.boxplot(x='Job Level', y='Environment Satisfaction', data=df)
plt.title('Environment Satisfaction by Job Level')
plt.show()

# %% [markdown]
# **What is the distribution of 'Training Times Last Year'?**

# %%
# Plotting the distribution of 'Training Times Last Year'
plt.figure(figsize=(10, 6))
sns.histplot(df['Training Times Last Year'], bins=10, kde=True)
plt.title('Distribution of Training Times Last Year')
plt.xlabel('Training Times Last Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **How is 'Monthly Income' distributed across different 'Job Roles'?**

# %%
# Creating a bar plot for 'Monthly Income' across different 'Job Roles'
plt.figure(figsize=(14, 8))
sns.barplot(x='Job Role', y='Monthly Income', data=df)
plt.title('Monthly Income Across Different Job Roles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **What is the distribution of 'Age' among employees who work overtime?**

# %%
# Creating a histogram for 'Age' of employees who work overtime
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Over Time'] == 'Yes']['Age'], bins=20, kde=True)
plt.title('Age Distribution of Employees Working Overtime')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **What is the distribution of 'Years Since Last Promotion'?**

# %%
# Plotting the distribution of 'Years Since Last Promotion'
plt.figure(figsize=(10, 6))
sns.histplot(df['Years Since Last Promotion'], bins=15, kde=True)
plt.title('Distribution of Years Since Last Promotion')
plt.xlabel('Years Since Last Promotion')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **How does 'Gender' impact 'Attrition'?**

# %%
# Creating a count plot for 'Attrition' based on 'Gender'
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', hue='Attrition', data=df)
plt.title('Impact of Gender on Attrition')
plt.show()

# %% [markdown]
# **What is the distribution of 'Monthly Income' for employees with different levels of 'Job Involvement'?**

# %%
# Creating a bar plot for 'Monthly Income' across different levels of 'Job Involvement'
plt.figure(figsize=(12, 8))
sns.barplot(x='Job Involvement', y='Monthly Income', data=df)
plt.title('Monthly Income Across Different Levels of Job Involvement')
plt.show()

# %% [markdown]
# **How is 'Distance From Home' related to 'Years at Company'?**

# %%
# Creating a scatter plot for 'Distance From Home' vs 'Years at Company'
plt.figure(figsize=(10, 8))
sns.scatterplot(x='Distance From Home', y='Years At Company', data=df, hue='Attrition')
plt.title('Distance From Home vs Years at Company')
plt.xlabel('Distance From Home')
plt.ylabel('Years At Company')
plt.legend()
plt.show()

# %% [markdown]
# **What is the distribution of 'Training Times Last Year' for employees who have 'Attrition'?**

# %%
# Plotting the distribution of 'Training Times Last Year' for employees with 'Attrition'
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Attrition'] == 'Yes']['Training Times Last Year'], bins=10, kde=True)
plt.title('Distribution of Training Times Last Year for Employees with Attrition')
plt.xlabel('Training Times Last Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **How does 'Education' impact 'Monthly Income'?**

# %%
# Creating a bar plot for 'Monthly Income' based on 'Education' level
plt.figure(figsize=(10, 6))
sns.barplot(x='Education', y='Monthly Income', data=df)
plt.title('Impact of Education on Monthly Income')
plt.show()

# %% [markdown]
# **What is the distribution of 'Percent Salary Hike' for different 'Job Levels'?**

# %%
# Plotting the distribution of 'Percent Salary Hike' across different 'Job Levels'
plt.figure(figsize=(12, 8))
sns.histplot(x='Percent Salary Hike', hue='Job Level', data=df, bins=15, kde=True, multiple="stack")
plt.title('Distribution of Percent Salary Hike Across Job Levels')
plt.xlabel('Percent Salary Hike')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **How does 'Job Role' correlate with 'Years in Current Role'?**

# %%
# Creating a bar plot for 'Years in Current Role' across different 'Job Roles'
plt.figure(figsize=(14, 8))
sns.barplot(x='Job Role', y='Years In Current Role', data=df)
plt.title('Years in Current Role Across Different Job Roles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **What is the distribution of 'Monthly Rate' for employees in different 'Departments'?**

# %%
# Creating a boxplot for 'Monthly Rate' across different 'Departments'
plt.figure(figsize=(12, 8))
sns.boxplot(x='Department', y='Monthly Rate', data=df)
plt.title('Monthly Rate Across Different Departments')
plt.show()

# %% [markdown]
# **How is 'Stock Option Level' distributed among employees based on 'Gender'?**

# %%
# Creating a count plot for 'Stock Option Level' based on 'Gender'
plt.figure(figsize=(10, 6))
sns.countplot(x='Stock Option Level', hue='Gender', data=df)
plt.title('Distribution of Stock Option Level Based on Gender')
plt.show()

# %% [markdown]
# **How does 'Environment Satisfaction' vary with 'Business Travel'?**

# %%
# Creating a bar plot for 'Environment Satisfaction' across different levels of 'Business Travel'
plt.figure(figsize=(10, 6))
sns.barplot(x='Business Travel', y='Environment Satisfaction', data=df)
plt.title('Environment Satisfaction Across Different Levels of Business Travel')
plt.show()

# %% [markdown]
# **What is the distribution of 'Daily Rate' for employees who work overtime?**

# %%
# Creating a histogram for 'Daily Rate' of employees who work overtime
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Over Time'] == 'Yes']['Daily Rate'], bins=20, kde=True)
plt.title('Daily Rate Distribution of Employees Working Overtime')
plt.xlabel('Daily Rate')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting the distribution of 'Years With Curr Manager'
plt.figure(figsize=(10, 6))
sns.histplot(df['Years With Curr Manager'], bins=15, kde=True)
plt.title('Distribution of Years With Current Manager')
plt.xlabel('Years With Current Manager')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting the distribution of 'Years With Curr Manager'
plt.figure(figsize=(10, 6))
sns.histplot(df['Years With Curr Manager'], bins=15, kde=True)
plt.title('Distribution of Years With Current Manager')
plt.xlabel('Years With Current Manager')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **What is the distribution of 'Num Companies Worked' for employees with 'Attrition'?**

# %%
# Plotting the distribution of 'Num Companies Worked' for employees with 'Attrition'
plt.figure(figsize=(10, 6))
sns.histplot(df[df['Attrition'] == 'Yes']['Num Companies Worked'], bins=10, kde=True)
plt.title('Distribution of Num Companies Worked for Employees with Attrition')
plt.xlabel('Num Companies Worked')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **What is the distribution of 'Relationship Satisfaction' based on 'Marital Status'?**

# %%
# Creating a pie chart for 'Relationship Satisfaction' based on 'Marital Status'
plt.figure(figsize=(10, 6))
relationship_satisfaction_counts = df['Relationship Satisfaction'].value_counts()
plt.pie(relationship_satisfaction_counts, labels=relationship_satisfaction_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Relationship Satisfaction Distribution Based on Marital Status')
plt.show()

# %% [markdown]
# **How is 'Job Level' distributed among employees based on 'Over Time'?**

# %%
# Creating a bar plot for 'Job Level' based on 'Over Time'
plt.figure(figsize=(10, 6))
sns.countplot(x='Job Level', hue='Over Time', data=df)
plt.title('Job Level Distribution Based on Overtime')
plt.show()
